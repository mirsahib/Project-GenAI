# %%
import pandas as pd
df = pd.read_csv('../data/BigBasket.csv')

# %%
df.head()
# Out:
#      ProductName   Brand   Price  DiscountPrice  \
# 0  Onion (Loose)  Fresho   69.75           52.0
# 1          Onion  Fresho  174.35          130.0
# 2  Onion (Loose)  Fresho   34.87           26.0
# 3          Onion  Fresho   69.74           52.0
# 4  Onion (Loose)  Fresho  174.37          129.0
#
#                                            Image_Url Quantity  \
# 0  https://www.bigbasket.com/media/uploads/p/l/40...     2 kg
# 1  https://www.bigbasket.com/media/uploads/p/l/12...     5 kg
# 2  https://www.bigbasket.com/media/uploads/p/l/10...     1 kg
# 3  https://www.bigbasket.com/media/uploads/p/l/12...     2 kg
# 4  https://www.bigbasket.com/media/uploads/p/l/10...     5 kg
#
#               Category             SubCategory  \
# 0  Fruits & Vegetables  Potato, Onion & Tomato
# 1  Fruits & Vegetables  Potato, Onion & Tomato
# 2  Fruits & Vegetables  Potato, Onion & Tomato
# 3  Fruits & Vegetables  Potato, Onion & Tomato
# 4  Fruits & Vegetables  Potato, Onion & Tomato
#
# ...

# %%
# Group by Category to count the occurrences
category_counts = df['Category'].value_counts().reset_index()
category_counts.columns = ['Category', 'Counts']

# Check the aggregated data
category_counts.head()
# Out:
#                    Category  Counts
# 0          Beauty & Hygiene    3789
# 1    Kitchen, Garden & Pets    1321
# 2  Foodgrains, Oil & Masala     718
# 3      Cleaning & Household     562
# 4      Gourmet & World Food     490

# %%
import matplotlib.pyplot as plt

# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(category_counts['Category'], category_counts['Counts'], color='skyblue')

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Counts')
plt.title('Counts of Categories')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Group by Category to count the occurrences
category_counts = df['SubCategory'].value_counts().reset_index()
category_counts.columns = ['SubCategory', 'Counts']

# Check the aggregated data
category_counts.head()
# Out:
#               SubCategory  Counts
# 0               Face Care     825
# 1  Supplements & Proteins     240
# 2                    Face     207
# 3               Body Care     205
# 4   Shampoo & Conditioner     201

# %%
import matplotlib.pyplot as plt

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(subcategory_counts['SubCategory'], subcategory_counts['Counts'], color='coral')

# Add labels and title
plt.xlabel('SubCategory')
plt.ylabel('Counts')
plt.title('Counts of Subcategories')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       3 # Create a bar plot
#       4 plt.figure(figsize=(12, 6))
# ----> 5 plt.bar(subcategory_counts['Subcategory'], subcategory_counts['Counts'], color='coral')
#       7 # Add labels and title
#       8 plt.xlabel('Subcategory')
#
# NameError: name 'subcategory_counts' is not defined
